# %%
from __future__ import division

from models import *
from utils.utils import *
from utils.datasets import *
from utils.parse_config import *

import os
import sys
import time
import datetime
import argparse
import tqdm
import easydict

import torch
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision import transforms
from torch.autograd import Variable
import torch.optim as optim


def evaluate(model, path, iou_thres, conf_thres, nms_thres, img_size, batch_size):
    model.eval()

    # Get dataloader
    dataset = ListDataset(path, img_size=img_size, augment=False, multiscale=False)
    dataloader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=False, num_workers=1, collate_fn=dataset.collate_fn
    )

    Tensor = torch.cuda.FloatTensor if torch.cuda.is_available() else torch.FloatTensor

    labels = []
    sample_metrics = []  # List of tuples (TP, confs, pred)
    for batch_i, (_, imgs, targets) in enumerate(tqdm.tqdm(dataloader, desc="Detecting objects")):

        # Extract labels
        labels += targets[:, 1].tolist()
        # Rescale target
        targets[:, 2:] = xywh2xyxy(targets[:, 2:])
        targets[:, 2:] *= img_size

        imgs = Variable(imgs.type(Tensor), requires_grad=False)

        with torch.no_grad():
            outputs = model(imgs)
            outputs = non_max_suppression(outputs, conf_thres=conf_thres, nms_thres=nms_thres)

        sample_metrics += get_batch_statistics(outputs, targets, iou_threshold=iou_thres)

    # Concatenate sample statistics
    true_positives, pred_scores, pred_labels = [np.concatenate(x, 0) for x in list(zip(*sample_metrics))]
    precision, recall, AP, f1, ap_class = ap_per_class(true_positives, pred_scores, pred_labels, labels)

    return precision, recall, AP, f1, ap_class


if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    args = parser.parse_args(args=[])
#     parser.add_argument("--batch_size", type=int, default=8, help="size of each image batch")
#     parser.add_argument("--model_def", type=str, default="config/yolov3.cfg", help="path to model definition file")
#     parser.add_argument("--data_config", type=str, default="config/coco.data", help="path to data config file")
#     parser.add_argument("--weights_path", type=str, default="weights/yolov3.weights", help="path to weights file")
#     parser.add_argument("--class_path", type=str, default="data/coco.names", help="path to class label file")
#     parser.add_argument("--iou_thres", type=float, default=0.5, help="iou threshold required to qualify as detected")
#     parser.add_argument("--conf_thres", type=float, default=0.001, help="object confidence threshold")
#     parser.add_argument("--nms_thres", type=float, default=0.5, help="iou thresshold for non-maximum suppression")
#     parser.add_argument("--n_cpu", type=int, default=8, help="number of cpu threads to use during batch generation")
#     parser.add_argument("--img_size", type=int, default=416, help="size of each image dimension")
#     opt = parser.parse_args()
    args = easydict.EasyDict({
        "batch_size": 6,
        "model_def":r'D:/Ivan/Test_data/IvanMadeDataSet/Yolo_front/config/yolov3_832.cfg',
        "data_config":r'D:/Ivan/Test_data/IvanMadeDataSet/Yolo_front_test/config/coco.data',
        "weights_path":r'D:/Ivan/YoloCheckpoints/OID_front_1_832/70.weights',
        "class_path": r'D:/Ivan/Test_data/IvanMadeDataSet/Yolo_front/config/coco.names',
        "iou_thres": 0.5,
        "conf_thres":0.8,
        "nms_thres": 0.5,
        "n_cpu": 2,
        "img_size": 832
    })
    opt = args
    print(opt)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
######## make a new data set
    data_config = parse_data_config(opt.data_config)
    valid_path = data_config["test"]
#     class_names = load_classes(data_config["names"])
    class_names= load_classes(opt.class_path)

    # Initiate model
    model = Darknet(opt.model_def).to(device)
    if opt.weights_path.endswith(".weights"):
        # Load darknet weights
        model.load_darknet_weights(opt.weights_path)
    else:
        # Load checkpoint weights
        model.load_state_dict(torch.load(opt.weights_path))

    print("Compute mAP...")

    precision, recall, AP, f1, ap_class = evaluate(
        model,
        path=valid_path,
        iou_thres=opt.iou_thres,
        conf_thres=opt.conf_thres,
        nms_thres=opt.nms_thres,
        img_size=opt.img_size,
        batch_size=opt.batch_size,
    )

    print("Average Precisions:")
    for i, c in enumerate(ap_class):
        print(f"+ Class '{c}' ({class_names[c]}) - AP: {AP[i]}")

    print(f"mAP: {AP.mean()}")
    print(f"precision: {precision}")
    print(f"recall: {recall} ")
    print(f"precision: {precision.mean()}")
    print(f"recall: {recall.mean()} ")
# Out:
# {'batch_size': 6, 'model_def': 'D:/Ivan/Test_data/IvanMadeDataSet/Yolo_front/config/yolov3_832.cfg', 'data_config': 'D:/Ivan/Test_data/IvanMadeDataSet/Yolo_front_test/config/coco.data', 'weights_path': 'D:/Ivan/YoloCheckpoints/OID_front_1_832/70.weights', 'class_path': 'D:/Ivan/Test_data/IvanMadeDataSet/Yolo_front/config/coco.names', 'iou_thres': 0.5, 'conf_thres': 0.8, 'nms_thres': 0.5, 'n_cpu': 2, 'img_size': 832}
# Compute mAP...
# Detecting objects: 100%|█████████████████████████████████████████████████████████████| 135/135 [01:28<00:00,  1.99it/s]
# Computing AP: 100%|██████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.40it/s]
# Average Precisions:
# + Class '0' (cars) - AP: 0.023193602080831703
# mAP: 0.023193602080831703
# precision: [0.0087363]
# recall: [0.54739084]
# precision: 0.008736296422197672
# recall: 0.5473908413205538

# %%
print('D:/Ivan/YoloCheckpoints/OID_front_1_832/'+str(70)+'.weights')
# Out:
# D:/Ivan/YoloCheckpoints/OID_front_1_832/70.weights

# %%
from __future__ import division

from models import *
from utils.utils import *
from utils.datasets import *
from utils.parse_config import *

import os
import sys
import time
import datetime
import argparse
import tqdm
import easydict

import torch
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision import transforms
from torch.autograd import Variable
import torch.optim as optim
import pandas as pd


def evaluate(model, path, iou_thres, conf_thres, nms_thres, img_size, batch_size):
    model.eval()

    # Get dataloader
    dataset = ListDataset(path, img_size=img_size, augment=False, multiscale=False)
    dataloader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=False, num_workers=1, collate_fn=dataset.collate_fn
    )

    Tensor = torch.cuda.FloatTensor if torch.cuda.is_available() else torch.FloatTensor

    labels = []
    sample_metrics = []  # List of tuples (TP, confs, pred)
    for batch_i, (_, imgs, targets) in enumerate(tqdm.tqdm(dataloader, desc="Detecting objects")):

        # Extract labels
        labels += targets[:, 1].tolist()
        # Rescale target
        targets[:, 2:] = xywh2xyxy(targets[:, 2:])
        targets[:, 2:] *= img_size

        imgs = Variable(imgs.type(Tensor), requires_grad=False)

        with torch.no_grad():
            outputs = model(imgs)
            outputs = non_max_suppression(outputs, conf_thres=conf_thres, nms_thres=nms_thres)

        sample_metrics += get_batch_statistics(outputs, targets, iou_threshold=iou_thres)

    # Concatenate sample statistics
    true_positives, pred_scores, pred_labels = [np.concatenate(x, 0) for x in list(zip(*sample_metrics))]
    precision, recall, AP, f1, ap_class = ap_per_class(true_positives, pred_scores, pred_labels, labels)

    return precision, recall, AP, f1, ap_class

if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    args = parser.parse_args(args=[])
    args = easydict.EasyDict({
        "batch_size": 6,
        "model_def":r'D:/Ivan/Test_data/IvanMadeDataSet/Yolo_front/config/yolov3_832.cfg',
        "data_config":r'D:/Ivan/Test_data/IvanMadeDataSet/Yolo_front_test/config/coco.data',
        "weights_path":r'D:/Ivan/YoloCheckpoints/OID_front_1_832/70.weights',
        "class_path": r'D:/Ivan/Test_data/IvanMadeDataSet/Yolo_front/config/coco.names',
        "iou_thres": 0.5,
        "conf_thres":0.998,
        "nms_thres": 0.5,
        "n_cpu": 2,
        "img_size": 832
    })
    opt = args
    print(opt)
    cols = ['weights','recall','precision','AP','f1']
   
    
    path = r'D:/Ivan/YoloCheckpoints/OID_front_1_832/'

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    data_config = parse_data_config(opt.data_config)
    valid_path = data_config["test"]
    class_names= load_classes(opt.class_path)
   
    for i in range(77,160):
        try:
            print(i)
            df = pd.DataFrame(columns = cols)
             # Initiate model
            model = Darknet(opt.model_def).to(device)
            weights_path = path+str(i)+'.weights'
            if opt.weights_path.endswith(".weights"):
                # Load darknet weights
                model.load_darknet_weights(weights_path)
            else:
                # Load checkpoint weights
                model.load_state_dict(torch.load(weights_path))

            print("Compute mAP...")

            precision, recall, AP, f1, ap_class = evaluate(
                model,
                path=valid_path,
                iou_thres=opt.iou_thres,
                conf_thres=opt.conf_thres,
                nms_thres=opt.nms_thres,
                img_size=opt.img_size,
                batch_size=opt.batch_size,
            )
            df.loc[i] = [i, recall[0],precision[0], AP.mean(), f1[0]]
            print("Average Precisions:")
            for i, c in enumerate(ap_class):
                print(f"+ Class '{c}' ({class_names[c]}) - AP: {AP[i]}")

            print(f"mAP: {AP.mean()}")
            print(f"precision: {precision.mean()}")
            print(f"recall: {recall.mean()} ")
            df.to_csv( path+'OID_front_1_832_2.csv',mode='a',header= False)
#             model.zero_grad()
#             del model
        except:
            del model
            print('unable to test '+ str(i))
            pass
#     df.to_csv( path+'OID_front_1_832.csv')
# Out:
# {'batch_size': 6, 'model_def': 'D:/Ivan/Test_data/IvanMadeDataSet/Yolo_front/config/yolov3_832.cfg', 'data_config': 'D:/Ivan/Test_data/IvanMadeDataSet/Yolo_front_test/config/coco.data', 'weights_path': 'D:/Ivan/YoloCheckpoints/OID_front_1_832/70.weights', 'class_path': 'D:/Ivan/Test_data/IvanMadeDataSet/Yolo_front/config/coco.names', 'iou_thres': 0.5, 'conf_thres': 0.8, 'nms_thres': 0.5, 'n_cpu': 2, 'img_size': 832}
# 77
# Compute mAP...
# Detecting objects:  10%|██████▍                                                       | 14/135 [00:11<01:15,  1.61it/s]
# unable to test 77
# 78
# Compute mAP...
# Detecting objects:   0%|                                                                       | 0/135 [00:00<?, ?it/s]
# Detecting objects:   1%|▍                                                              | 1/135 [00:02<04:57,  2.22s/it]
# Detecting objects:   1%|▉                                                              | 2/135 [00:02<03:52,  1.75s/it]
# Detecting objects:   2%|█▍                                                             | 3/135 [00:03<03:07,  1.42s/it]
# Detecting objects:   3%|█▊                                                             | 4/135 [00:04<02:35,  1.19s/it]
# Detecting objects:   4%|██▎                                                            | 5/135 [00:04<02:14,  1.04s/it]
# Detecting objects:   4%|██▊                                                            | 6/135 [00:05<01:58,  1.09it/s]
# Detecting objects:   5%|███▎                                                           | 7/135 [00:06<01:45,  1.22it/s]
# Detecting objects:   6%|███▋                                                           | 8/135 [00:06<01:35,  1.32it/s]
# Detecting objects:   7%|████▏                                                          | 9/135 [00:07<01:31,  1.37it/s]
# Detecting objects:   7%|████▌                                                         | 10/135 [00:07<01:25,  1.45it/s]
# Detecting objects:   8%|█████                                                         | 11/135 [00:08<01:22,  1.50it/s]
# Detecting objects:   9%|█████▌                                                        | 12/135 [00:09<01:19,  1.54it/s]
# Detecting objects:  10%|█████▉                                                        | 13/135 [00:09<01:19,  1.54it/s]
# Detecting objects:  10%|██████▍                                                       | 14/135 [00:10<01:18,  1.55it/s]
# Detecting objects:  11%|██████▉                                                       | 15/135 [00:11<01:16,  1.56it/s]
# Detecting objects:  12%|███████▎                                                      | 16/135 [00:11<01:17,  1.54it/s]
# Detecting objects:  13%|███████▊                                                      | 17/135 [00:12<01:15,  1.57it/s]
# Detecting objects:  13%|████████▎                                                     | 18/135 [00:13<01:15,  1.56it/s]
# Detecting objects:  14%|████████▋                                                     | 19/135 [00:13<01:13,  1.57it/s]
# Detecting objects:  15%|█████████▏                                                    | 20/135 [00:14<01:11,  1.61it/s]
# Detecting objects:  16%|█████████▋                                                    | 21/135 [00:14<01:10,  1.62it/s]
# Detecting objects:  16%|██████████                                                    | 22/135 [00:15<01:09,  1.62it/s]
# Detecting objects:  17%|██████████▌                                                   | 23/135 [00:16<01:08,  1.64it/s]
# Detecting objects:  18%|███████████                                                   | 24/135 [00:16<01:08,  1.61it/s]
# Detecting objects:  19%|███████████▍                                                  | 25/135 [00:17<01:07,  1.62it/s]
# Detecting objects:  19%|███████████▉                                                  | 26/135 [00:17<01:08,  1.59it/s]
# Detecting objects:  20%|████████████▍                                                 | 27/135 [00:18<01:08,  1.59it/s]
# Detecting objects:  21%|████████████▊                                                 | 28/135 [00:19<01:09,  1.54it/s]
# Detecting objects:  21%|█████████████▎                                                | 29/135 [00:19<01:07,  1.57it/s]
# Detecting objects:  22%|█████████████▊                                                | 30/135 [00:20<01:07,  1.56it/s]
# Detecting objects:  23%|██████████████▏                                               | 31/135 [00:21<01:07,  1.54it/s]
# Detecting objects:  24%|██████████████▋                                               | 32/135 [00:21<01:05,  1.58it/s]
# Detecting objects:  24%|███████████████▏                                              | 33/135 [00:22<01:05,  1.56it/s]
# Detecting objects:  25%|███████████████▌                                              | 34/135 [00:23<01:06,  1.52it/s]
# Detecting objects:  26%|████████████████                                              | 35/135 [00:23<01:07,  1.48it/s]
# Detecting objects:  27%|████████████████▌                                             | 36/135 [00:24<01:06,  1.48it/s]
# Detecting objects:  27%|████████████████▉                                             | 37/135 [00:25<01:04,  1.51it/s]
# Detecting objects:  28%|█████████████████▍                                            | 38/135 [00:25<01:05,  1.49it/s]
# Detecting objects:  29%|█████████████████▉                                            | 39/135 [00:26<01:03,  1.50it/s]
# Detecting objects:  30%|██████████████████▎                                           | 40/135 [00:27<01:02,  1.53it/s]
# Detecting objects:  30%|██████████████████▊                                           | 41/135 [00:27<00:59,  1.57it/s]
# Detecting objects:  31%|███████████████████▎                                          | 42/135 [00:28<00:58,  1.60it/s]
# Detecting objects:  32%|███████████████████▋                                          | 43/135 [00:28<00:57,  1.60it/s]
# Detecting objects:  33%|████████████████████▏                                         | 44/135 [00:29<00:58,  1.56it/s]
# Detecting objects:  33%|████████████████████▋                                         | 45/135 [00:30<00:57,  1.56it/s]
# Detecting objects:  34%|█████████████████████▏                                        | 46/135 [00:30<00:57,  1.55it/s]
# Detecting objects:  35%|█████████████████████▌                                        | 47/135 [00:31<00:55,  1.59it/s]
# Detecting objects:  36%|██████████████████████                                        | 48/135 [00:32<00:55,  1.57it/s]
# Detecting objects:  36%|██████████████████████▌                                       | 49/135 [00:32<00:54,  1.57it/s]
# Detecting objects:  37%|██████████████████████▉                                       | 50/135 [00:33<00:54,  1.57it/s]
# Detecting objects:  38%|███████████████████████▍                                      | 51/135 [00:34<00:53,  1.57it/s]
# Detecting objects:  39%|███████████████████████▉                                      | 52/135 [00:34<00:53,  1.56it/s]
# Detecting objects:  39%|████████████████████████▎                                     | 53/135 [00:35<00:51,  1.59it/s]
# Detecting objects:  40%|████████████████████████▊                                     | 54/135 [00:36<00:51,  1.57it/s]
# Detecting objects:  41%|█████████████████████████▎                                    | 55/135 [00:36<00:49,  1.60it/s]
# Detecting objects:  41%|█████████████████████████▋                                    | 56/135 [00:37<00:48,  1.62it/s]
# Detecting objects:  42%|██████████████████████████▏                                   | 57/135 [00:37<00:49,  1.58it/s]
# Detecting objects:  43%|██████████████████████████▋                                   | 58/135 [00:38<00:49,  1.55it/s]
# Detecting objects:  44%|███████████████████████████                                   | 59/135 [00:39<00:48,  1.57it/s]
# Detecting objects:  44%|███████████████████████████▌                                  | 60/135 [00:39<00:48,  1.54it/s]
# Detecting objects:  45%|████████████████████████████                                  | 61/135 [00:40<00:47,  1.57it/s]
# Detecting objects:  46%|████████████████████████████▍                                 | 62/135 [00:41<00:46,  1.59it/s]
# Detecting objects:  47%|████████████████████████████▉                                 | 63/135 [00:41<00:44,  1.61it/s]
# Detecting objects:  47%|█████████████████████████████▍                                | 64/135 [00:42<00:44,  1.60it/s]
# Detecting objects:  48%|█████████████████████████████▊                                | 65/135 [00:42<00:43,  1.62it/s]
# Detecting objects:  49%|██████████████████████████████▎                               | 66/135 [00:43<00:42,  1.61it/s]
# Detecting objects:  50%|██████████████████████████████▊                               | 67/135 [00:44<00:41,  1.63it/s]
# Detecting objects:  50%|███████████████████████████████▏                              | 68/135 [00:44<00:41,  1.60it/s]
# Detecting objects:  51%|███████████████████████████████▋                              | 69/135 [00:45<00:42,  1.56it/s]
# Detecting objects:  52%|████████████████████████████████▏                             | 70/135 [00:46<00:41,  1.58it/s]
# Detecting objects:  53%|████████████████████████████████▌                             | 71/135 [00:46<00:40,  1.58it/s]
# Detecting objects:  53%|█████████████████████████████████                             | 72/135 [00:47<00:39,  1.59it/s]
# Detecting objects:  54%|█████████████████████████████████▌                            | 73/135 [00:47<00:39,  1.59it/s]
# Detecting objects:  55%|█████████████████████████████████▉                            | 74/135 [00:48<00:37,  1.61it/s]
# Detecting objects:  56%|██████████████████████████████████▍                           | 75/135 [00:49<00:38,  1.58it/s]
# Detecting objects:  56%|██████████████████████████████████▉                           | 76/135 [00:49<00:38,  1.54it/s]
# Detecting objects:  57%|███████████████████████████████████▎                          | 77/135 [00:50<00:37,  1.56it/s]
# Detecting objects:  58%|███████████████████████████████████▊                          | 78/135 [00:51<00:35,  1.61it/s]
# Detecting objects:  59%|████████████████████████████████████▎                         | 79/135 [00:51<00:33,  1.67it/s]
# Detecting objects:  59%|████████████████████████████████████▋                         | 80/135 [00:52<00:33,  1.66it/s]
# Detecting objects:  60%|█████████████████████████████████████▏                        | 81/135 [00:52<00:34,  1.57it/s]
# Detecting objects:  61%|█████████████████████████████████████▋                        | 82/135 [00:53<00:33,  1.59it/s]
# Detecting objects:  61%|██████████████████████████████████████                        | 83/135 [00:54<00:32,  1.60it/s]
# Detecting objects:  62%|██████████████████████████████████████▌                       | 84/135 [00:54<00:32,  1.57it/s]
# Detecting objects:  63%|███████████████████████████████████████                       | 85/135 [00:55<00:31,  1.60it/s]
# Detecting objects:  64%|███████████████████████████████████████▍                      | 86/135 [00:56<00:30,  1.60it/s]
# Detecting objects:  64%|███████████████████████████████████████▉                      | 87/135 [00:56<00:29,  1.61it/s]
# Detecting objects:  65%|████████████████████████████████████████▍                     | 88/135 [00:57<00:28,  1.65it/s]
# Detecting objects:  66%|████████████████████████████████████████▊                     | 89/135 [00:57<00:28,  1.61it/s]
# Detecting objects:  67%|█████████████████████████████████████████▎                    | 90/135 [00:58<00:27,  1.64it/s]
# Detecting objects:  67%|█████████████████████████████████████████▊                    | 91/135 [00:59<00:26,  1.63it/s]
# Detecting objects:  68%|██████████████████████████████████████████▎                   | 92/135 [00:59<00:26,  1.63it/s]
# Detecting objects:  69%|██████████████████████████████████████████▋                   | 93/135 [01:00<00:25,  1.64it/s]
# Detecting objects:  70%|███████████████████████████████████████████▏                  | 94/135 [01:00<00:25,  1.64it/s]
# Detecting objects:  70%|███████████████████████████████████████████▋                  | 95/135 [01:01<00:24,  1.63it/s]
# Detecting objects:  71%|████████████████████████████████████████████                  | 96/135 [01:02<00:23,  1.66it/s]
# Detecting objects:  72%|████████████████████████████████████████████▌                 | 97/135 [01:02<00:23,  1.61it/s]
# Detecting objects:  73%|█████████████████████████████████████████████                 | 98/135 [01:03<00:22,  1.62it/s]
# Detecting objects:  73%|█████████████████████████████████████████████▍                | 99/135 [01:04<00:21,  1.64it/s]
# Detecting objects:  74%|█████████████████████████████████████████████▏               | 100/135 [01:04<00:22,  1.59it/s]
# Detecting objects:  75%|█████████████████████████████████████████████▋               | 101/135 [01:05<00:20,  1.63it/s]
# Detecting objects:  76%|██████████████████████████████████████████████               | 102/135 [01:05<00:19,  1.66it/s]
# Detecting objects:  76%|██████████████████████████████████████████████▌              | 103/135 [01:06<00:19,  1.64it/s]
# Detecting objects:  77%|██████████████████████████████████████████████▉              | 104/135 [01:07<00:18,  1.64it/s]
# Detecting objects:  78%|███████████████████████████████████████████████▍             | 105/135 [01:07<00:18,  1.63it/s]
# Detecting objects:  79%|███████████████████████████████████████████████▉             | 106/135 [01:08<00:17,  1.65it/s]
# Detecting objects:  79%|████████████████████████████████████████████████▎            | 107/135 [01:08<00:16,  1.65it/s]
# Detecting objects:  80%|████████████████████████████████████████████████▊            | 108/135 [01:09<00:15,  1.69it/s]
# Detecting objects:  81%|█████████████████████████████████████████████████▎           | 109/135 [01:10<00:15,  1.66it/s]
# Detecting objects:  81%|█████████████████████████████████████████████████▋           | 110/135 [01:10<00:15,  1.62it/s]
# Detecting objects:  82%|██████████████████████████████████████████████████▏          | 111/135 [01:11<00:14,  1.62it/s]
# Detecting objects:  83%|██████████████████████████████████████████████████▌          | 112/135 [01:11<00:13,  1.65it/s]
# Detecting objects:  84%|███████████████████████████████████████████████████          | 113/135 [01:12<00:13,  1.69it/s]
# Detecting objects:  84%|███████████████████████████████████████████████████▌         | 114/135 [01:13<00:12,  1.65it/s]
# Detecting objects:  85%|███████████████████████████████████████████████████▉         | 115/135 [01:13<00:12,  1.65it/s]
# Detecting objects:  86%|████████████████████████████████████████████████████▍        | 116/135 [01:14<00:11,  1.62it/s]
# Detecting objects:  87%|████████████████████████████████████████████████████▊        | 117/135 [01:15<00:11,  1.62it/s]
# Detecting objects:  87%|█████████████████████████████████████████████████████▎       | 118/135 [01:15<00:10,  1.63it/s]
# Detecting objects:  88%|█████████████████████████████████████████████████████▊       | 119/135 [01:16<00:09,  1.62it/s]
# Detecting objects:  89%|██████████████████████████████████████████████████████▏      | 120/135 [01:16<00:09,  1.63it/s]
# Detecting objects:  90%|██████████████████████████████████████████████████████▋      | 121/135 [01:17<00:08,  1.66it/s]
# Detecting objects:  90%|███████████████████████████████████████████████████████▏     | 122/135 [01:18<00:07,  1.64it/s]
# Detecting objects:  91%|███████████████████████████████████████████████████████▌     | 123/135 [01:18<00:07,  1.66it/s]
# Detecting objects:  92%|████████████████████████████████████████████████████████     | 124/135 [01:19<00:06,  1.64it/s]
# Detecting objects:  93%|████████████████████████████████████████████████████████▍    | 125/135 [01:19<00:06,  1.62it/s]
# Detecting objects:  93%|████████████████████████████████████████████████████████▉    | 126/135 [01:20<00:05,  1.62it/s]
# Detecting objects:  94%|█████████████████████████████████████████████████████████▍   | 127/135 [01:21<00:04,  1.62it/s]
# Detecting objects:  95%|█████████████████████████████████████████████████████████▊   | 128/135 [01:21<00:04,  1.57it/s]
# Detecting objects:  96%|██████████████████████████████████████████████████████████▎  | 129/135 [01:22<00:03,  1.58it/s]
# Detecting objects:  96%|██████████████████████████████████████████████████████████▋  | 130/135 [01:23<00:03,  1.56it/s]
# Detecting objects:  97%|███████████████████████████████████████████████████████████▏ | 131/135 [01:23<00:02,  1.54it/s]
# Detecting objects:  98%|███████████████████████████████████████████████████████████▋ | 132/135 [01:24<00:01,  1.52it/s]
# Detecting objects:  99%|████████████████████████████████████████████████████████████ | 133/135 [01:25<00:01,  1.55it/s]
# Detecting objects:  99%|████████████████████████████████████████████████████████████▌| 134/135 [01:25<00:00,  1.59it/s]
# Detecting objects: 100%|█████████████████████████████████████████████████████████████| 135/135 [01:25<00:00,  2.05it/s]
# Computing AP:   0%|                                                                              | 0/1 [00:00<?, ?it/s]
# Computing AP: 100%|██████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.45it/s]
# Average Precisions:
# + Class '0' (cars) - AP: 0.03208775452186725
# mAP: 0.03208775452186725
# precision: 0.013860763913134557
# recall: 0.422790202342918
# 79
# Compute mAP...
# Detecting objects:   0%|                                                                       | 0/135 [00:00<?, ?it/s]
# Detecting objects:   1%|▍                                                              | 1/135 [00:01<03:36,  1.61s/it]
# Detecting objects:   1%|▉                                                              | 2/135 [00:02<03:02,  1.37s/it]
# Detecting objects:   2%|█▍                                                             | 3/135 [00:03<02:35,  1.18s/it]
# Detecting objects:   3%|█▊                                                             | 4/135 [00:03<02:15,  1.04s/it]
# Detecting objects:   4%|██▎                                                            | 5/135 [00:04<02:05,  1.04it/s]
# Detecting objects:   4%|██▊                                                            | 6/135 [00:05<01:54,  1.13it/s]
# Detecting objects:   5%|███▎                                                           | 7/135 [00:06<01:48,  1.18it/s]
# Detecting objects:   6%|███▋                                                           | 8/135 [00:06<01:41,  1.25it/s]
# Detecting objects:   7%|████▏                                                          | 9/135 [00:07<01:38,  1.28it/s]
# Detecting objects:   7%|████▌                                                         | 10/135 [00:08<01:32,  1.35it/s]
# Detecting objects:   8%|█████                                                         | 11/135 [00:08<01:31,  1.36it/s]
# Detecting objects:   9%|█████▌                                                        | 12/135 [00:09<01:26,  1.42it/s]
# Detecting objects:  10%|█████▉                                                        | 13/135 [00:10<01:28,  1.39it/s]
# Detecting objects:  10%|██████▍                                                       | 14/135 [00:11<01:28,  1.37it/s]
# Detecting objects:  11%|██████▉                                                       | 15/135 [00:11<01:25,  1.41it/s]
# Detecting objects:  12%|███████▎                                                      | 16/135 [00:12<01:24,  1.41it/s]
# Detecting objects:  13%|███████▊                                                      | 17/135 [00:13<01:19,  1.48it/s]
# Detecting objects:  13%|████████▎                                                     | 18/135 [00:13<01:18,  1.48it/s]
# Detecting objects:  14%|████████▋                                                     | 19/135 [00:14<01:20,  1.45it/s]
# Detecting objects:  15%|█████████▏                                                    | 20/135 [00:15<01:19,  1.45it/s]
# Detecting objects:  16%|█████████▋                                                    | 21/135 [00:15<01:16,  1.50it/s]
# Detecting objects:  16%|██████████                                                    | 22/135 [00:16<01:18,  1.45it/s]
# Detecting objects:  17%|██████████▌                                                   | 23/135 [00:17<01:18,  1.42it/s]
# Detecting objects:  18%|███████████                                                   | 24/135 [00:17<01:19,  1.40it/s]
# Detecting objects:  19%|███████████▍                                                  | 25/135 [00:18<01:17,  1.41it/s]
# Detecting objects:  19%|███████████▉                                                  | 26/135 [00:19<01:20,  1.36it/s]
# Detecting objects:  20%|████████████▍                                                 | 27/135 [00:20<01:16,  1.41it/s]
# Detecting objects:  21%|████████████▊                                                 | 28/135 [00:21<01:25,  1.25it/s]
# Detecting objects:  21%|█████████████▎                                                | 29/135 [00:21<01:20,  1.31it/s]
# Detecting objects:  22%|█████████████▊                                                | 30/135 [00:22<01:21,  1.29it/s]
# Detecting objects:  23%|██████████████▏                                               | 31/135 [00:23<01:21,  1.27it/s]
# Detecting objects:  24%|██████████████▋                                               | 32/135 [00:23<01:15,  1.36it/s]
# Detecting objects:  24%|███████████████▏                                              | 33/135 [00:24<01:12,  1.40it/s]
# Detecting objects:  25%|███████████████▌                                              | 34/135 [00:25<01:10,  1.43it/s]
# Detecting objects:  26%|████████████████                                              | 35/135 [00:26<01:13,  1.35it/s]
# Detecting objects:  27%|████████████████▌                                             | 36/135 [00:26<01:09,  1.42it/s]
# Detecting objects:  27%|████████████████▉                                             | 37/135 [00:27<01:07,  1.46it/s]
# Detecting objects:  28%|█████████████████▍                                            | 38/135 [00:28<01:07,  1.43it/s]
# Detecting objects:  29%|█████████████████▉                                            | 39/135 [00:28<01:08,  1.41it/s]
# Detecting objects:  30%|██████████████████▎                                           | 40/135 [00:29<01:08,  1.40it/s]
# Detecting objects:  30%|██████████████████▊                                           | 41/135 [00:30<01:03,  1.48it/s]
# Detecting objects:  31%|███████████████████▎                                          | 42/135 [00:30<01:03,  1.47it/s]
# Detecting objects:  32%|███████████████████▋                                          | 43/135 [00:31<01:03,  1.45it/s]
# Detecting objects:  33%|████████████████████▏                                         | 44/135 [00:32<01:04,  1.41it/s]
# Detecting objects:  33%|████████████████████▋                                         | 45/135 [00:33<01:05,  1.37it/s]
# Detecting objects:  34%|█████████████████████▏                                        | 46/135 [00:33<01:02,  1.42it/s]
# Detecting objects:  35%|█████████████████████▌                                        | 47/135 [00:34<01:00,  1.44it/s]
# Detecting objects:  36%|██████████████████████                                        | 48/135 [00:35<01:04,  1.35it/s]
# Detecting objects:  36%|██████████████████████▌                                       | 49/135 [00:36<01:02,  1.37it/s]
# Detecting objects:  37%|██████████████████████▉                                       | 50/135 [00:36<01:02,  1.37it/s]
# Detecting objects:  38%|███████████████████████▍                                      | 51/135 [00:37<01:00,  1.39it/s]
# Detecting objects:  39%|███████████████████████▉                                      | 52/135 [00:38<00:57,  1.44it/s]
# Detecting objects:  39%|████████████████████████▎                                     | 53/135 [00:38<00:54,  1.49it/s]
# Detecting objects:  40%|████████████████████████▊                                     | 54/135 [00:39<00:56,  1.42it/s]
# Detecting objects:  41%|█████████████████████████▎                                    | 55/135 [00:40<00:55,  1.44it/s]
# Detecting objects:  41%|█████████████████████████▋                                    | 56/135 [00:40<00:54,  1.44it/s]
# Detecting objects:  42%|██████████████████████████▏                                   | 57/135 [00:41<00:54,  1.44it/s]
# Detecting objects:  43%|██████████████████████████▋                                   | 58/135 [00:42<00:54,  1.42it/s]
# Detecting objects:  44%|███████████████████████████                                   | 59/135 [00:42<00:53,  1.42it/s]
# Detecting objects:  44%|███████████████████████████▌                                  | 60/135 [00:43<00:53,  1.40it/s]
# Detecting objects:  45%|████████████████████████████                                  | 61/135 [00:44<00:50,  1.48it/s]
# Detecting objects:  46%|████████████████████████████▍                                 | 62/135 [00:44<00:49,  1.46it/s]
# Detecting objects:  47%|████████████████████████████▉                                 | 63/135 [00:45<00:48,  1.50it/s]
# Detecting objects:  47%|█████████████████████████████▍                                | 64/135 [00:46<00:48,  1.45it/s]
# Detecting objects:  48%|█████████████████████████████▊                                | 65/135 [00:46<00:45,  1.52it/s]
# Detecting objects:  49%|██████████████████████████████▎                               | 66/135 [00:47<00:47,  1.45it/s]
# Detecting objects:  50%|██████████████████████████████▊                               | 67/135 [00:48<00:45,  1.49it/s]
# Detecting objects:  50%|███████████████████████████████▏                              | 68/135 [00:49<00:45,  1.49it/s]
# Detecting objects:  51%|███████████████████████████████▋                              | 69/135 [00:49<00:46,  1.41it/s]
# Detecting objects:  52%|████████████████████████████████▏                             | 70/135 [00:50<00:45,  1.44it/s]
# Detecting objects:  53%|████████████████████████████████▌                             | 71/135 [00:51<00:45,  1.42it/s]
# Detecting objects:  53%|█████████████████████████████████                             | 72/135 [00:51<00:43,  1.45it/s]
# Detecting objects:  54%|█████████████████████████████████▌                            | 73/135 [00:52<00:42,  1.46it/s]
# Detecting objects:  55%|█████████████████████████████████▉                            | 74/135 [00:53<00:40,  1.49it/s]
# Detecting objects:  56%|██████████████████████████████████▍                           | 75/135 [00:53<00:41,  1.44it/s]
# Detecting objects:  56%|██████████████████████████████████▉                           | 76/135 [00:54<00:42,  1.40it/s]
# Detecting objects:  57%|███████████████████████████████████▎                          | 77/135 [00:55<00:41,  1.40it/s]
# Detecting objects:  58%|███████████████████████████████████▊                          | 78/135 [00:55<00:38,  1.49it/s]
# Detecting objects:  59%|████████████████████████████████████▎                         | 79/135 [00:56<00:37,  1.51it/s]
# Detecting objects:  59%|████████████████████████████████████▋                         | 80/135 [00:57<00:35,  1.54it/s]
# Detecting objects:  60%|█████████████████████████████████████▏                        | 81/135 [00:57<00:36,  1.47it/s]
# Detecting objects:  61%|█████████████████████████████████████▋                        | 82/135 [00:58<00:36,  1.46it/s]
# Detecting objects:  61%|██████████████████████████████████████                        | 83/135 [00:59<00:35,  1.49it/s]
# Detecting objects:  62%|██████████████████████████████████████▌                       | 84/135 [00:59<00:34,  1.47it/s]
# Detecting objects:  63%|███████████████████████████████████████                       | 85/135 [01:00<00:33,  1.48it/s]
# Detecting objects:  64%|███████████████████████████████████████▍                      | 86/135 [01:01<00:33,  1.47it/s]
# Detecting objects:  64%|███████████████████████████████████████▉                      | 87/135 [01:02<00:32,  1.47it/s]
# Detecting objects:  65%|████████████████████████████████████████▍                     | 88/135 [01:02<00:30,  1.53it/s]
# Detecting objects:  66%|████████████████████████████████████████▊                     | 89/135 [01:03<00:31,  1.48it/s]
# Detecting objects:  67%|█████████████████████████████████████████▎                    | 90/135 [01:04<00:30,  1.47it/s]
# Detecting objects:  67%|█████████████████████████████████████████▊                    | 91/135 [01:04<00:29,  1.50it/s]
# Detecting objects:  68%|██████████████████████████████████████████▎                   | 92/135 [01:05<00:28,  1.49it/s]
# Detecting objects:  69%|██████████████████████████████████████████▋                   | 93/135 [01:05<00:27,  1.53it/s]
# Detecting objects:  70%|███████████████████████████████████████████▏                  | 94/135 [01:06<00:27,  1.51it/s]
# Detecting objects:  70%|███████████████████████████████████████████▋                  | 95/135 [01:07<00:25,  1.57it/s]
# Detecting objects:  71%|████████████████████████████████████████████                  | 96/135 [01:07<00:24,  1.59it/s]
# Detecting objects:  72%|████████████████████████████████████████████▌                 | 97/135 [01:08<00:24,  1.52it/s]
# Detecting objects:  73%|█████████████████████████████████████████████                 | 98/135 [01:09<00:24,  1.49it/s]
# Detecting objects:  73%|█████████████████████████████████████████████▍                | 99/135 [01:10<00:25,  1.43it/s]
# Detecting objects:  74%|█████████████████████████████████████████████▏               | 100/135 [01:10<00:24,  1.45it/s]
# Detecting objects:  75%|█████████████████████████████████████████████▋               | 101/135 [01:11<00:22,  1.52it/s]
# Detecting objects:  76%|██████████████████████████████████████████████               | 102/135 [01:11<00:21,  1.54it/s]
# Detecting objects:  76%|██████████████████████████████████████████████▌              | 103/135 [01:12<00:21,  1.48it/s]
# Detecting objects:  77%|██████████████████████████████████████████████▉              | 104/135 [01:13<00:21,  1.46it/s]
# Detecting objects:  78%|███████████████████████████████████████████████▍             | 105/135 [01:14<00:21,  1.43it/s]
# Detecting objects:  79%|███████████████████████████████████████████████▉             | 106/135 [01:14<00:20,  1.43it/s]
# Detecting objects:  79%|████████████████████████████████████████████████▎            | 107/135 [01:15<00:18,  1.47it/s]
# Detecting objects:  80%|████████████████████████████████████████████████▊            | 108/135 [01:16<00:17,  1.51it/s]
# Detecting objects:  81%|█████████████████████████████████████████████████▎           | 109/135 [01:16<00:17,  1.50it/s]
# Detecting objects:  81%|█████████████████████████████████████████████████▋           | 110/135 [01:17<00:17,  1.46it/s]
# Detecting objects:  82%|██████████████████████████████████████████████████▏          | 111/135 [01:18<00:16,  1.49it/s]
# Detecting objects:  83%|██████████████████████████████████████████████████▌          | 112/135 [01:18<00:14,  1.56it/s]
# Detecting objects:  84%|███████████████████████████████████████████████████          | 113/135 [01:19<00:13,  1.58it/s]
# Detecting objects:  84%|███████████████████████████████████████████████████▌         | 114/135 [01:20<00:14,  1.48it/s]
# Detecting objects:  85%|███████████████████████████████████████████████████▉         | 115/135 [01:20<00:13,  1.53it/s]
# Detecting objects:  86%|████████████████████████████████████████████████████▍        | 116/135 [01:21<00:12,  1.48it/s]
# Detecting objects:  87%|████████████████████████████████████████████████████▊        | 117/135 [01:22<00:12,  1.47it/s]
# Detecting objects:  87%|█████████████████████████████████████████████████████▎       | 118/135 [01:22<00:11,  1.50it/s]
# Detecting objects:  88%|█████████████████████████████████████████████████████▊       | 119/135 [01:23<00:10,  1.50it/s]
# Detecting objects:  89%|██████████████████████████████████████████████████████▏      | 120/135 [01:24<00:09,  1.52it/s]
# Detecting objects:  90%|██████████████████████████████████████████████████████▋      | 121/135 [01:24<00:09,  1.53it/s]
# Detecting objects:  90%|███████████████████████████████████████████████████████▏     | 122/135 [01:25<00:08,  1.56it/s]
# Detecting objects:  91%|███████████████████████████████████████████████████████▌     | 123/135 [01:25<00:07,  1.60it/s]
# Detecting objects:  92%|████████████████████████████████████████████████████████     | 124/135 [01:26<00:07,  1.55it/s]
# Detecting objects:  93%|████████████████████████████████████████████████████████▍    | 125/135 [01:27<00:06,  1.55it/s]
# Detecting objects:  93%|████████████████████████████████████████████████████████▉    | 126/135 [01:27<00:05,  1.55it/s]
# Detecting objects:  94%|█████████████████████████████████████████████████████████▍   | 127/135 [01:28<00:04,  1.60it/s]
# Detecting objects:  95%|█████████████████████████████████████████████████████████▊   | 128/135 [01:29<00:04,  1.53it/s]
# Detecting objects:  96%|██████████████████████████████████████████████████████████▎  | 129/135 [01:29<00:03,  1.53it/s]
# Detecting objects:  96%|██████████████████████████████████████████████████████████▋  | 130/135 [01:30<00:03,  1.52it/s]
# Detecting objects:  97%|███████████████████████████████████████████████████████████▏ | 131/135 [01:31<00:02,  1.42it/s]
# Detecting objects:  98%|███████████████████████████████████████████████████████████▋ | 132/135 [01:32<00:02,  1.36it/s]
# Detecting objects:  99%|████████████████████████████████████████████████████████████ | 133/135 [01:32<00:01,  1.43it/s]
# Detecting objects:  99%|████████████████████████████████████████████████████████████▌| 134/135 [01:33<00:00,  1.46it/s]
# Detecting objects: 100%|█████████████████████████████████████████████████████████████| 135/135 [01:33<00:00,  1.92it/s]
# Computing AP:   0%|                                                                              | 0/1 [00:00<?, ?it/s]
# Computing AP: 100%|██████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.87it/s]
# Average Precisions:
# + Class '0' (cars) - AP: 0.024917055012779778
# mAP: 0.024917055012779778
# precision: 0.010731052984574111
# recall: 0.47710330138445156
# 80
# Compute mAP...
# Detecting objects:   0%|                                                                       | 0/135 [00:00<?, ?it/s]
# Detecting objects:   1%|▍                                                              | 1/135 [00:01<03:38,  1.63s/it]
# Detecting objects:   1%|▉                                                              | 2/135 [00:02<03:00,  1.36s/it]
# Detecting objects:   2%|█▍                                                             | 3/135 [00:03<02:33,  1.16s/it]
# Detecting objects:   3%|█▊                                                             | 4/135 [00:03<02:15,  1.04s/it]
# Detecting objects:   4%|██▎                                                            | 5/135 [00:04<02:02,  1.06it/s]
# Detecting objects:   4%|██▊                                                            | 6/135 [00:05<01:50,  1.16it/s]
# Detecting objects:   5%|███▎                                                           | 7/135 [00:05<01:42,  1.25it/s]
# Detecting objects:   6%|███▋                                                           | 8/135 [00:06<01:34,  1.34it/s]
# Detecting objects:   7%|████▏                                                          | 9/135 [00:07<01:32,  1.35it/s]
# Detecting objects:   7%|████▌                                                         | 10/135 [00:07<01:28,  1.40it/s]
# Detecting objects:   8%|█████                                                         | 11/135 [00:08<01:27,  1.42it/s]
# Detecting objects:   9%|█████▌                                                        | 12/135 [00:09<01:26,  1.42it/s]
# Detecting objects:  10%|█████▉                                                        | 13/135 [00:10<01:28,  1.39it/s]
# Detecting objects:  10%|██████▍                                                       | 14/135 [00:10<01:27,  1.38it/s]
# Detecting objects:  11%|██████▉                                                       | 15/135 [00:11<01:24,  1.42it/s]
# Detecting objects:  12%|███████▎                                                      | 16/135 [00:12<01:24,  1.40it/s]
# Detecting objects:  13%|███████▊                                                      | 17/135 [00:12<01:22,  1.43it/s]
# Detecting objects:  13%|████████▎                                                     | 18/135 [00:13<01:21,  1.43it/s]
# Detecting objects:  14%|████████▋                                                     | 19/135 [00:14<01:19,  1.46it/s]
# Detecting objects:  15%|█████████▏                                                    | 20/135 [00:14<01:17,  1.49it/s]
# Detecting objects:  16%|█████████▋                                                    | 21/135 [00:15<01:14,  1.53it/s]
# Detecting objects:  16%|██████████                                                    | 22/135 [00:16<01:15,  1.49it/s]
# Detecting objects:  17%|██████████▌                                                   | 23/135 [00:16<01:15,  1.49it/s]
# Detecting objects:  18%|███████████                                                   | 24/135 [00:17<01:17,  1.44it/s]
# Detecting objects:  19%|███████████▍                                                  | 25/135 [00:18<01:14,  1.47it/s]
# Detecting objects:  19%|███████████▉                                                  | 26/135 [00:18<01:16,  1.42it/s]
# Detecting objects:  20%|████████████▍                                                 | 27/135 [00:19<01:15,  1.43it/s]
# Detecting objects:  21%|████████████▊                                                 | 28/135 [00:20<01:20,  1.33it/s]
# Detecting objects:  21%|█████████████▎                                                | 29/135 [00:21<01:17,  1.37it/s]
# Detecting objects:  22%|█████████████▊                                                | 30/135 [00:22<01:20,  1.30it/s]
# Detecting objects:  23%|██████████████▏                                               | 31/135 [00:22<01:19,  1.31it/s]
# Detecting objects:  24%|██████████████▋                                               | 32/135 [00:23<01:14,  1.39it/s]
# Detecting objects:  24%|███████████████▏                                              | 33/135 [00:24<01:11,  1.42it/s]
# Detecting objects:  25%|███████████████▌                                              | 34/135 [00:24<01:11,  1.41it/s]
# Detecting objects:  26%|████████████████                                              | 35/135 [00:25<01:14,  1.33it/s]
# Detecting objects:  27%|████████████████▌                                             | 36/135 [00:26<01:09,  1.42it/s]
# Detecting objects:  27%|████████████████▉                                             | 37/135 [00:26<01:07,  1.46it/s]
# Detecting objects:  28%|█████████████████▍                                            | 38/135 [00:27<01:07,  1.43it/s]
# Detecting objects:  29%|█████████████████▉                                            | 39/135 [00:28<01:06,  1.43it/s]
# Detecting objects:  30%|██████████████████▎                                           | 40/135 [00:28<01:05,  1.45it/s]
# Detecting objects:  30%|██████████████████▊                                           | 41/135 [00:29<01:02,  1.50it/s]
# Detecting objects:  31%|███████████████████▎                                          | 42/135 [00:30<01:02,  1.50it/s]
# Detecting objects:  32%|███████████████████▋                                          | 43/135 [00:31<01:03,  1.44it/s]
# Detecting objects:  33%|████████████████████▏                                         | 44/135 [00:31<01:05,  1.40it/s]
# Detecting objects:  33%|████████████████████▋                                         | 45/135 [00:32<01:04,  1.40it/s]
# Detecting objects:  34%|█████████████████████▏                                        | 46/135 [00:33<01:04,  1.38it/s]
# Detecting objects:  35%|█████████████████████▌                                        | 47/135 [00:33<01:01,  1.44it/s]
# Detecting objects:  36%|██████████████████████                                        | 48/135 [00:34<01:02,  1.39it/s]
# Detecting objects:  36%|██████████████████████▌                                       | 49/135 [00:35<01:00,  1.42it/s]
# Detecting objects:  37%|██████████████████████▉                                       | 50/135 [00:36<00:59,  1.42it/s]
# Detecting objects:  38%|███████████████████████▍                                      | 51/135 [00:36<00:59,  1.41it/s]
# Detecting objects:  39%|███████████████████████▉                                      | 52/135 [00:37<00:58,  1.42it/s]
# Detecting objects:  39%|████████████████████████▎                                     | 53/135 [00:38<00:55,  1.47it/s]
# Detecting objects:  40%|████████████████████████▊                                     | 54/135 [00:38<00:56,  1.44it/s]
# Detecting objects:  41%|█████████████████████████▎                                    | 55/135 [00:39<00:54,  1.47it/s]
# Detecting objects:  41%|█████████████████████████▋                                    | 56/135 [00:40<00:54,  1.44it/s]
# Detecting objects:  42%|██████████████████████████▏                                   | 57/135 [00:40<00:57,  1.36it/s]
# Detecting objects:  43%|██████████████████████████▋                                   | 58/135 [00:41<00:57,  1.34it/s]
# Detecting objects:  44%|███████████████████████████                                   | 59/135 [00:42<00:56,  1.36it/s]
# Detecting objects:  44%|███████████████████████████▌                                  | 60/135 [00:43<00:54,  1.37it/s]
# Detecting objects:  45%|████████████████████████████                                  | 61/135 [00:43<00:53,  1.39it/s]
# Detecting objects:  46%|████████████████████████████▍                                 | 62/135 [00:44<00:51,  1.42it/s]
# Detecting objects:  47%|████████████████████████████▉                                 | 63/135 [00:45<00:48,  1.47it/s]
# Detecting objects:  47%|█████████████████████████████▍                                | 64/135 [00:45<00:48,  1.47it/s]
# Detecting objects:  48%|█████████████████████████████▊                                | 65/135 [00:46<00:45,  1.52it/s]
# Detecting objects:  49%|██████████████████████████████▎                               | 66/135 [00:47<00:47,  1.46it/s]
# Detecting objects:  50%|██████████████████████████████▊                               | 67/135 [00:47<00:44,  1.51it/s]
# Detecting objects:  50%|███████████████████████████████▏                              | 68/135 [00:48<00:44,  1.51it/s]
# Detecting objects:  51%|███████████████████████████████▋                              | 69/135 [00:49<00:46,  1.43it/s]
# Detecting objects:  52%|████████████████████████████████▏                             | 70/135 [00:49<00:45,  1.43it/s]
# Detecting objects:  53%|████████████████████████████████▌                             | 71/135 [00:50<00:44,  1.43it/s]
# Detecting objects:  53%|█████████████████████████████████                             | 72/135 [00:51<00:43,  1.45it/s]
# Detecting objects:  54%|█████████████████████████████████▌                            | 73/135 [00:52<00:43,  1.43it/s]
# Detecting objects:  55%|█████████████████████████████████▉                            | 74/135 [00:52<00:41,  1.49it/s]
# Detecting objects:  56%|██████████████████████████████████▍                           | 75/135 [00:53<00:41,  1.45it/s]
# Detecting objects:  56%|██████████████████████████████████▉                           | 76/135 [00:54<00:41,  1.43it/s]
# Detecting objects:  57%|███████████████████████████████████▎                          | 77/135 [00:54<00:39,  1.47it/s]
# Detecting objects:  58%|███████████████████████████████████▊                          | 78/135 [00:55<00:37,  1.52it/s]
# Detecting objects:  59%|████████████████████████████████████▎                         | 79/135 [00:55<00:36,  1.54it/s]
# Detecting objects:  59%|████████████████████████████████████▋                         | 80/135 [00:56<00:35,  1.54it/s]
# Detecting objects:  60%|█████████████████████████████████████▏                        | 81/135 [00:57<00:35,  1.52it/s]
# Detecting objects:  61%|█████████████████████████████████████▋                        | 82/135 [00:57<00:34,  1.52it/s]
# Detecting objects:  61%|██████████████████████████████████████                        | 83/135 [00:58<00:34,  1.52it/s]
# Detecting objects:  62%|██████████████████████████████████████▌                       | 84/135 [00:59<00:34,  1.48it/s]
# Detecting objects:  63%|███████████████████████████████████████                       | 85/135 [00:59<00:32,  1.54it/s]
# Detecting objects:  64%|███████████████████████████████████████▍                      | 86/135 [01:00<00:32,  1.51it/s]
# Detecting objects:  64%|███████████████████████████████████████▉                      | 87/135 [01:01<00:32,  1.48it/s]
# Detecting objects:  65%|████████████████████████████████████████▍                     | 88/135 [01:01<00:31,  1.51it/s]
# Detecting objects:  66%|████████████████████████████████████████▊                     | 89/135 [01:02<00:30,  1.51it/s]
# Detecting objects:  67%|█████████████████████████████████████████▎                    | 90/135 [01:03<00:29,  1.53it/s]
# Detecting objects:  67%|█████████████████████████████████████████▊                    | 91/135 [01:03<00:28,  1.52it/s]
# Detecting objects:  68%|██████████████████████████████████████████▎                   | 92/135 [01:04<00:28,  1.50it/s]
# Detecting objects:  69%|██████████████████████████████████████████▋                   | 93/135 [01:05<00:27,  1.54it/s]
# Detecting objects:  70%|███████████████████████████████████████████▏                  | 94/135 [01:05<00:27,  1.51it/s]
# Detecting objects:  70%|███████████████████████████████████████████▋                  | 95/135 [01:06<00:26,  1.50it/s]
# Detecting objects:  71%|████████████████████████████████████████████                  | 96/135 [01:07<00:25,  1.52it/s]
# Detecting objects:  72%|████████████████████████████████████████████▌                 | 97/135 [01:07<00:25,  1.50it/s]
# Detecting objects:  73%|█████████████████████████████████████████████                 | 98/135 [01:08<00:24,  1.48it/s]
# Detecting objects:  73%|█████████████████████████████████████████████▍                | 99/135 [01:09<00:24,  1.50it/s]
# Detecting objects:  74%|█████████████████████████████████████████████▏               | 100/135 [01:09<00:24,  1.46it/s]
# Detecting objects:  75%|█████████████████████████████████████████████▋               | 101/135 [01:10<00:22,  1.53it/s]
# Detecting objects:  76%|██████████████████████████████████████████████               | 102/135 [01:11<00:21,  1.55it/s]
# Detecting objects:  76%|██████████████████████████████████████████████▌              | 103/135 [01:11<00:20,  1.53it/s]
# Detecting objects:  77%|██████████████████████████████████████████████▉              | 104/135 [01:12<00:20,  1.50it/s]
# Detecting objects:  78%|███████████████████████████████████████████████▍             | 105/135 [01:13<00:20,  1.47it/s]
# Detecting objects:  79%|███████████████████████████████████████████████▉             | 106/135 [01:13<00:19,  1.48it/s]
# Detecting objects:  79%|████████████████████████████████████████████████▎            | 107/135 [01:14<00:18,  1.53it/s]
# Detecting objects:  80%|████████████████████████████████████████████████▊            | 108/135 [01:15<00:17,  1.58it/s]
# Detecting objects:  81%|█████████████████████████████████████████████████▎           | 109/135 [01:15<00:17,  1.53it/s]
# Detecting objects:  81%|█████████████████████████████████████████████████▋           | 110/135 [01:16<00:16,  1.52it/s]
# Detecting objects:  82%|██████████████████████████████████████████████████▏          | 111/135 [01:17<00:15,  1.51it/s]
# Detecting objects:  83%|██████████████████████████████████████████████████▌          | 112/135 [01:17<00:15,  1.50it/s]
# Detecting objects:  84%|███████████████████████████████████████████████████          | 113/135 [01:18<00:13,  1.58it/s]
# Detecting objects:  84%|███████████████████████████████████████████████████▌         | 114/135 [01:19<00:13,  1.53it/s]
# Detecting objects:  85%|███████████████████████████████████████████████████▉         | 115/135 [01:19<00:12,  1.56it/s]
# ...
# Detecting objects:   4%|██▊                                                            | 6/135 [00:03<01:14,  1.74it/s]
# Detecting objects:   5%|███▎                                                           | 7/135 [00:03<01:07,  1.90it/s]
# Detecting objects:   6%|███▋                                                           | 8/135 [00:04<01:02,  2.02it/s]
# Detecting objects:   7%|████▏                                                          | 9/135 [00:04<01:00,  2.09it/s]
# Detecting objects:   7%|████▌                                                         | 10/135 [00:05<00:57,  2.16it/s]
# Detecting objects:   8%|█████                                                         | 11/135 [00:05<00:55,  2.24it/s]
# Detecting objects:   9%|█████▌                                                        | 12/135 [00:05<00:53,  2.30it/s]
# Detecting objects:  10%|█████▉                                                        | 13/135 [00:06<00:52,  2.33it/s]
# Detecting objects:  10%|██████▍                                                       | 14/135 [00:06<00:51,  2.34it/s]
# Detecting objects:  11%|██████▉                                                       | 15/135 [00:07<00:50,  2.36it/s]
# Detecting objects:  12%|███████▎                                                      | 16/135 [00:07<00:49,  2.39it/s]
# Detecting objects:  13%|███████▊                                                      | 17/135 [00:08<00:49,  2.39it/s]
# Detecting objects:  13%|████████▎                                                     | 18/135 [00:08<00:49,  2.36it/s]
# Detecting objects:  14%|████████▋                                                     | 19/135 [00:08<00:48,  2.39it/s]
# Detecting objects:  15%|█████████▏                                                    | 20/135 [00:09<00:48,  2.38it/s]
# Detecting objects:  16%|█████████▋                                                    | 21/135 [00:09<00:47,  2.39it/s]
# Detecting objects:  16%|██████████                                                    | 22/135 [00:10<00:47,  2.39it/s]
# Detecting objects:  17%|██████████▌                                                   | 23/135 [00:10<00:47,  2.37it/s]
# Detecting objects:  18%|███████████                                                   | 24/135 [00:10<00:47,  2.35it/s]
# Detecting objects:  19%|███████████▍                                                  | 25/135 [00:11<00:46,  2.37it/s]
# Detecting objects:  19%|███████████▉                                                  | 26/135 [00:11<00:46,  2.36it/s]
# Detecting objects:  20%|████████████▍                                                 | 27/135 [00:12<00:45,  2.37it/s]
# Detecting objects:  21%|████████████▊                                                 | 28/135 [00:12<00:45,  2.34it/s]
# Detecting objects:  21%|█████████████▎                                                | 29/135 [00:13<00:44,  2.38it/s]
# Detecting objects:  22%|█████████████▊                                                | 30/135 [00:13<00:44,  2.37it/s]
# Detecting objects:  23%|██████████████▏                                               | 31/135 [00:13<00:44,  2.36it/s]
# Detecting objects:  24%|██████████████▋                                               | 32/135 [00:14<00:43,  2.38it/s]
# Detecting objects:  24%|███████████████▏                                              | 33/135 [00:14<00:43,  2.37it/s]
# Detecting objects:  25%|███████████████▌                                              | 34/135 [00:15<00:42,  2.39it/s]
# Detecting objects:  26%|████████████████                                              | 35/135 [00:15<00:42,  2.37it/s]
# Detecting objects:  27%|████████████████▌                                             | 36/135 [00:16<00:41,  2.38it/s]
# Detecting objects:  27%|████████████████▉                                             | 37/135 [00:16<00:40,  2.41it/s]
# Detecting objects:  28%|█████████████████▍                                            | 38/135 [00:16<00:40,  2.38it/s]
# Detecting objects:  29%|█████████████████▉                                            | 39/135 [00:17<00:40,  2.39it/s]
# Detecting objects:  30%|██████████████████▎                                           | 40/135 [00:17<00:39,  2.38it/s]
# Detecting objects:  30%|██████████████████▊                                           | 41/135 [00:18<00:39,  2.40it/s]
# Detecting objects:  31%|███████████████████▎                                          | 42/135 [00:18<00:38,  2.39it/s]
# Detecting objects:  32%|███████████████████▋                                          | 43/135 [00:18<00:38,  2.38it/s]
# Detecting objects:  33%|████████████████████▏                                         | 44/135 [00:19<00:38,  2.38it/s]
# Detecting objects:  33%|████████████████████▋                                         | 45/135 [00:19<00:38,  2.37it/s]
# Detecting objects:  34%|█████████████████████▏                                        | 46/135 [00:20<00:37,  2.38it/s]
# Detecting objects:  35%|█████████████████████▌                                        | 47/135 [00:20<00:36,  2.41it/s]
# Detecting objects:  36%|██████████████████████                                        | 48/135 [00:21<00:36,  2.37it/s]
# Detecting objects:  36%|██████████████████████▌                                       | 49/135 [00:21<00:36,  2.37it/s]
# Detecting objects:  37%|██████████████████████▉                                       | 50/135 [00:21<00:35,  2.36it/s]
# Detecting objects:  38%|███████████████████████▍                                      | 51/135 [00:22<00:35,  2.37it/s]
# Detecting objects:  39%|███████████████████████▉                                      | 52/135 [00:22<00:34,  2.38it/s]
# Detecting objects:  39%|████████████████████████▎                                     | 53/135 [00:23<00:34,  2.39it/s]
# Detecting objects:  40%|████████████████████████▊                                     | 54/135 [00:23<00:34,  2.38it/s]
# Detecting objects:  41%|█████████████████████████▎                                    | 55/135 [00:24<00:33,  2.38it/s]
# Detecting objects:  41%|█████████████████████████▋                                    | 56/135 [00:24<00:33,  2.37it/s]
# Detecting objects:  42%|██████████████████████████▏                                   | 57/135 [00:24<00:33,  2.34it/s]
# Detecting objects:  43%|██████████████████████████▋                                   | 58/135 [00:25<00:32,  2.36it/s]
# Detecting objects:  44%|███████████████████████████                                   | 59/135 [00:25<00:32,  2.35it/s]
# Detecting objects:  44%|███████████████████████████▌                                  | 60/135 [00:26<00:32,  2.34it/s]
# Detecting objects:  45%|████████████████████████████                                  | 61/135 [00:26<00:31,  2.35it/s]
# Detecting objects:  46%|████████████████████████████▍                                 | 62/135 [00:27<00:31,  2.35it/s]
# Detecting objects:  47%|████████████████████████████▉                                 | 63/135 [00:27<00:30,  2.37it/s]
# Detecting objects:  47%|█████████████████████████████▍                                | 64/135 [00:27<00:30,  2.34it/s]
# Detecting objects:  48%|█████████████████████████████▊                                | 65/135 [00:28<00:29,  2.38it/s]
# Detecting objects:  49%|██████████████████████████████▎                               | 66/135 [00:28<00:29,  2.37it/s]
# Detecting objects:  50%|██████████████████████████████▊                               | 67/135 [00:29<00:28,  2.37it/s]
# Detecting objects:  50%|███████████████████████████████▏                              | 68/135 [00:29<00:28,  2.38it/s]
# Detecting objects:  51%|███████████████████████████████▋                              | 69/135 [00:29<00:27,  2.36it/s]
# Detecting objects:  52%|████████████████████████████████▏                             | 70/135 [00:30<00:27,  2.39it/s]
# Detecting objects:  53%|████████████████████████████████▌                             | 71/135 [00:30<00:26,  2.40it/s]
# Detecting objects:  53%|█████████████████████████████████                             | 72/135 [00:31<00:26,  2.40it/s]
# Detecting objects:  54%|█████████████████████████████████▌                            | 73/135 [00:31<00:25,  2.40it/s]
# Detecting objects:  55%|█████████████████████████████████▉                            | 74/135 [00:32<00:25,  2.42it/s]
# Detecting objects:  56%|██████████████████████████████████▍                           | 75/135 [00:32<00:25,  2.40it/s]
# Detecting objects:  56%|██████████████████████████████████▉                           | 76/135 [00:32<00:24,  2.36it/s]
# Detecting objects:  57%|███████████████████████████████████▎                          | 77/135 [00:33<00:24,  2.37it/s]
# Detecting objects:  58%|███████████████████████████████████▊                          | 78/135 [00:33<00:23,  2.40it/s]
# Detecting objects:  59%|████████████████████████████████████▎                         | 79/135 [00:34<00:23,  2.42it/s]
# Detecting objects:  59%|████████████████████████████████████▋                         | 80/135 [00:34<00:22,  2.40it/s]
# Detecting objects:  60%|█████████████████████████████████████▏                        | 81/135 [00:34<00:22,  2.38it/s]
# Detecting objects:  61%|█████████████████████████████████████▋                        | 82/135 [00:35<00:22,  2.36it/s]
# Detecting objects:  61%|██████████████████████████████████████                        | 83/135 [00:35<00:21,  2.37it/s]
# Detecting objects:  62%|██████████████████████████████████████▌                       | 84/135 [00:36<00:21,  2.36it/s]
# Detecting objects:  63%|███████████████████████████████████████                       | 85/135 [00:36<00:21,  2.38it/s]
# Detecting objects:  64%|███████████████████████████████████████▍                      | 86/135 [00:37<00:20,  2.38it/s]
# Detecting objects:  64%|███████████████████████████████████████▉                      | 87/135 [00:37<00:20,  2.37it/s]
# Detecting objects:  65%|████████████████████████████████████████▍                     | 88/135 [00:37<00:19,  2.39it/s]
# Detecting objects:  66%|████████████████████████████████████████▊                     | 89/135 [00:38<00:19,  2.39it/s]
# Detecting objects:  67%|█████████████████████████████████████████▎                    | 90/135 [00:38<00:18,  2.39it/s]
# Detecting objects:  67%|█████████████████████████████████████████▊                    | 91/135 [00:39<00:18,  2.39it/s]
# Detecting objects:  68%|██████████████████████████████████████████▎                   | 92/135 [00:39<00:18,  2.37it/s]
# Detecting objects:  69%|██████████████████████████████████████████▋                   | 93/135 [00:40<00:17,  2.38it/s]
# Detecting objects:  70%|███████████████████████████████████████████▏                  | 94/135 [00:40<00:17,  2.41it/s]
# Detecting objects:  70%|███████████████████████████████████████████▋                  | 95/135 [00:40<00:16,  2.42it/s]
# Detecting objects:  71%|████████████████████████████████████████████                  | 96/135 [00:41<00:16,  2.43it/s]
# Detecting objects:  72%|████████████████████████████████████████████▌                 | 97/135 [00:41<00:15,  2.43it/s]
# Detecting objects:  73%|█████████████████████████████████████████████                 | 98/135 [00:42<00:15,  2.42it/s]
# Detecting objects:  73%|█████████████████████████████████████████████▍                | 99/135 [00:42<00:14,  2.40it/s]
# Detecting objects:  74%|█████████████████████████████████████████████▏               | 100/135 [00:42<00:14,  2.41it/s]
# Detecting objects:  75%|█████████████████████████████████████████████▋               | 101/135 [00:43<00:14,  2.42it/s]
# Detecting objects:  76%|██████████████████████████████████████████████               | 102/135 [00:43<00:13,  2.42it/s]
# Detecting objects:  76%|██████████████████████████████████████████████▌              | 103/135 [00:44<00:13,  2.40it/s]
# Detecting objects:  77%|██████████████████████████████████████████████▉              | 104/135 [00:44<00:12,  2.39it/s]
# Detecting objects:  78%|███████████████████████████████████████████████▍             | 105/135 [00:44<00:12,  2.41it/s]
# Detecting objects:  79%|███████████████████████████████████████████████▉             | 106/135 [00:45<00:12,  2.41it/s]
# Detecting objects:  79%|████████████████████████████████████████████████▎            | 107/135 [00:45<00:11,  2.42it/s]
# Detecting objects:  80%|████████████████████████████████████████████████▊            | 108/135 [00:46<00:11,  2.44it/s]
# Detecting objects:  81%|█████████████████████████████████████████████████▎           | 109/135 [00:46<00:10,  2.42it/s]
# Detecting objects:  81%|█████████████████████████████████████████████████▋           | 110/135 [00:47<00:10,  2.39it/s]
# Detecting objects:  82%|██████████████████████████████████████████████████▏          | 111/135 [00:47<00:10,  2.40it/s]
# Detecting objects:  83%|██████████████████████████████████████████████████▌          | 112/135 [00:47<00:09,  2.43it/s]
# Detecting objects:  84%|███████████████████████████████████████████████████          | 113/135 [00:48<00:09,  2.43it/s]
# Detecting objects:  84%|███████████████████████████████████████████████████▌         | 114/135 [00:48<00:08,  2.40it/s]
# Detecting objects:  85%|███████████████████████████████████████████████████▉         | 115/135 [00:49<00:08,  2.41it/s]
# Detecting objects:  86%|████████████████████████████████████████████████████▍        | 116/135 [00:49<00:07,  2.38it/s]
# Detecting objects:  87%|████████████████████████████████████████████████████▊        | 117/135 [00:49<00:07,  2.38it/s]
# Detecting objects:  87%|█████████████████████████████████████████████████████▎       | 118/135 [00:50<00:07,  2.39it/s]
# Detecting objects:  88%|█████████████████████████████████████████████████████▊       | 119/135 [00:50<00:06,  2.41it/s]
# Detecting objects:  89%|██████████████████████████████████████████████████████▏      | 120/135 [00:51<00:06,  2.43it/s]
# Detecting objects:  90%|██████████████████████████████████████████████████████▋      | 121/135 [00:51<00:05,  2.42it/s]
# Detecting objects:  90%|███████████████████████████████████████████████████████▏     | 122/135 [00:52<00:05,  2.41it/s]
# Detecting objects:  91%|███████████████████████████████████████████████████████▌     | 123/135 [00:52<00:04,  2.42it/s]
# Detecting objects:  92%|████████████████████████████████████████████████████████     | 124/135 [00:52<00:04,  2.39it/s]
# Detecting objects:  93%|████████████████████████████████████████████████████████▍    | 125/135 [00:53<00:04,  2.37it/s]
# Detecting objects:  93%|████████████████████████████████████████████████████████▉    | 126/135 [00:53<00:03,  2.36it/s]
# Detecting objects:  94%|█████████████████████████████████████████████████████████▍   | 127/135 [00:54<00:03,  2.39it/s]
# Detecting objects:  95%|█████████████████████████████████████████████████████████▊   | 128/135 [00:54<00:02,  2.38it/s]
# Detecting objects:  96%|██████████████████████████████████████████████████████████▎  | 129/135 [00:54<00:02,  2.38it/s]
# Detecting objects:  96%|██████████████████████████████████████████████████████████▋  | 130/135 [00:55<00:02,  2.38it/s]
# Detecting objects:  97%|███████████████████████████████████████████████████████████▏ | 131/135 [00:55<00:01,  2.35it/s]
# Detecting objects:  98%|███████████████████████████████████████████████████████████▋ | 132/135 [00:56<00:01,  2.31it/s]
# Detecting objects:  99%|████████████████████████████████████████████████████████████ | 133/135 [00:56<00:00,  2.35it/s]
# Detecting objects:  99%|████████████████████████████████████████████████████████████▌| 134/135 [00:57<00:00,  2.36it/s]
# Detecting objects: 100%|█████████████████████████████████████████████████████████████| 135/135 [00:57<00:00,  2.36it/s]
# Computing AP:   0%|                                                                              | 0/1 [00:00<?, ?it/s]
# Computing AP: 100%|██████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 38.43it/s]
# Average Precisions:
# + Class '0' (cars) - AP: 0.019319284405126452
# mAP: 0.019319284405126452
# precision: 0.022109917877447885
# recall: 0.26091586794462196
